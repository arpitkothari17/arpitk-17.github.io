# %%
# Import pandas and numpy libraries

import pandas as pd
import numpy as np

# %%
# Read the train data

train_df = pd.read_csv('Ames_train.csv')
train_df.head()
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  527402250           20        RL           NaN     12537   Pave   NaN
# 1  923225240          160        RM          41.0      2665   Pave   NaN
# 2  534178010           20        RL          80.0     10800   Pave   NaN
# 3  905452160           20        RL          75.0      9525   Pave   NaN
# 4  535376100           30        RL          60.0      5400   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN   NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN   NaN          NaN
# 2       Reg          Lvl    AllPub  ...         0     NaN   NaN          NaN
# 3       Reg          Lvl    AllPub  ...         0     NaN   NaN          NaN
# 4       Reg          Lvl    AllPub  ...         0     NaN   NaN          NaN
#
# ...

# %%
# For the example codes, I will only use 4 variables and the target price

train_df[['PID',
          'Gr Liv Area',
          'Garage Area',
          'Year Built',
          'Garage Finish',
          'SalePrice']].head()
# Out:
#          PID  Gr Liv Area  Garage Area  Year Built Garage Finish  SalePrice
# 0  527402250         1078        500.0        1971           Fin     149900
# 1  923225240         1475        336.0        1977           RFn     127000
# 2  534178010         1052        311.0        1963           Fin     127000
# 3  905452160         1172        366.0        1954           Fin     128000
# 4  535376100         1073        326.0        1921           Unf     108480

# %%
# We can also take a look at the test set.

test_df = pd.read_csv('Ames_test.csv')
test_df.head()
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526350040           20        RH          80.0     11622   Pave   NaN
# 1  526353030           20        RL          93.0     11160   Pave   NaN
# 2  527358200           85        RL          85.0     10625   Pave   NaN
# 3  527368020           60        FV           NaN      7500   Pave   NaN
# 4  527425090           20        RL          70.0     10500   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 2       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
#
# ...

# %%
train_df.shape
# Out:
# (2344, 81)

# %%
test_df.shape
# Out:
# (586, 81)

# %%
train_df.SalePrice.mean()
# Out:
# 181036.99530716724
